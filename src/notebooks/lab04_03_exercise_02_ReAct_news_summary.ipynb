# %% [markdown]
# Exercise 2 - Create a News Summary Tool
# Objective: Build a tool that can fetch and summarize recent news articles.
#
# Create a news summarization tool that works with the existing search functionality. This tool should take search results and create concise summaries of news articles.
#
# Instructions:
#
#
# Create a news_summarizer_tool that takes news content and creates summaries.
# The tool should extract key information: headline, date, main points.
# Format the output in a readable way.
# Test it by asking the agent to "search for recent AI news and summarize the top 3 articles".
# Starter Code:¶

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import BaseMessage, HumanMessage, ToolMessage

from langgraph.graph import StateGraph, END

from typing import (Annotated,Sequence,TypedDict)
from langchain_core.messages import BaseMessage
from langgraph.graph.message import add_messages

from langchain_openai import AzureChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain.tools import tool
import os
import json

# %%
@tool
def news_summarizer_tool(news_content: str) -> str:
    """
    Summarize news articles from search results.
    
    :param news_content: Raw news content or search results
    :return: A formatted summary of the news
    """
    # Parse the news content from search results
    try:
        # If news_content is JSON string, parse it
        if news_content.startswith('[') or news_content.startswith('{'):
            data = json.loads(news_content)
        else:
            # If it's plain text, treat as single article
            data = [{"title": "News Article", "content": news_content, "url": ""}]
        
        # Ensure data is a list
        if isinstance(data, dict):
            data = [data]
        
        summaries = []
        for i, article in enumerate(data[:3]):  # Limit to top 3 articles
            title = article.get('title', f'Article {i+1}')
            content = article.get('content', article.get('snippet', ''))
            url = article.get('url', '')
            
            # Extract main points (first 200 chars of content)
            main_points = content[:200] + "..." if len(content) > 200 else content
            
            summary = f"""
    📰 **{title}**
    🔗 {url}
    📝 **Summary:** {main_points}
    """
            summaries.append(summary)
        
        final_summary = "📊 **NEWS SUMMARY**\n" + "="*50 + "\n"
        final_summary += "\n".join(summaries)
        
        return final_summary
        
    except Exception as e:
        return f"Error processing news content: {str(e)}"
    pass

# TODO: Add to tools list and test with:
# "Find recent news about artificial intelligence and give me a summary"

# %%
# Initialize the Tavily search tool
search = TavilySearchResults()

@tool
def search_tool(query: str):
    """
    Search the web for information using Tavily API.

    :param query: The search query string
    :return: Search results related to the query
    """
    return search.invoke(query)

# %%
tools=[search_tool, news_summarizer_tool]
tools_by_name={ tool.name:tool for tool in tools}

# %%
# Configure ChatOpenAI for Azure OpenAI
deployment_name = "gpt-4o-mini"  # Replace with your actual deployment name

openai_llm = AzureChatOpenAI(
    azure_deployment=deployment_name,
    api_version=os.getenv("OPENAI_API_VERSION"),
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    temperature=0.7,
    model_name=deployment_name,
    max_retries=3,
    request_timeout=120,
    max_tokens=1024,
    top_p=0.95   
)

# %%
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", """
You are a helpful AI assistant that thinks step-by-step and uses tools when needed.

When responding to queries:
1. First, think about what information you need
2. Use available tools if you need current data or specific capabilities  
3. Provide clear, helpful responses based on your reasoning and any tool results

Always explain your thinking process to help users understand your approach.
"""),
    MessagesPlaceholder(variable_name="scratch_pad")
])

# binding the tools to the LLM
model_react = chat_prompt | openai_llm.bind_tools(tools)

# Agent state:


class AgentState(TypedDict):
    """The state of the agent."""
    # add_messages is a reducer
    # See https://langchain-ai.github.io/langgraph/concepts/low_level/#reducers
    messages: Annotated[Sequence[BaseMessage], add_messages]

# %%
user_query = "Find recent AI news and summarize the top 3 articles"

# %%
# tool execution node
def tool_node(state: AgentState):
    """Execute all tool calls from the last message in the state."""
    outputs = []
    for tool_call in state["messages"][-1].tool_calls:
        tool_result = tools_by_name[tool_call["name"]].invoke(tool_call["args"])
        outputs.append(
            ToolMessage(
                content=json.dumps(tool_result),
                name=tool_call["name"],
                tool_call_id=tool_call["id"],
            )
        )
    return {"messages": outputs}


# model invocation node
def call_model(state: AgentState):
    """Invoke the model with the current conversation state."""
    response = model_react.invoke({"scratch_pad": state["messages"]})
    return {"messages": [response]}


# decision logic node
def should_continue(state: AgentState):
    """Determine whether to continue with tool use or end the conversation."""
    messages = state["messages"]
    last_message = messages[-1]
    # If there is no function call, then we finish
    if not last_message.tool_calls:
        return "end"
    # Otherwise if there is, we continue
    else:
        return "continue"

# %% [markdown]
# then the graph itself:

# %%
# Define a new graph
workflow = StateGraph(AgentState)

# Define the two nodes we will cycle between
workflow.add_node("agent", call_model)
workflow.add_node("tools", tool_node)

# Add edges between nodes
workflow.add_edge("tools", "agent")  # After tools, always go back to agent

# Add conditional logic
workflow.add_conditional_edges(
    "agent",
    should_continue,
    {
        "continue": "tools",  # If tools needed, go to tools node
        "end": END,          # If done, end the conversation
    },
)

# Set entry point
workflow.set_entry_point("agent")

# Compile the graph
graph = workflow.compile()

# %% [markdown]
# run/test it

# %%
def print_stream(stream):
    """Helper function for formatting the stream nicely."""
    for s in stream:
        message = s["messages"][-1]
        if isinstance(message, tuple):
            print(message)
        else:
            message.pretty_print()

inputs = {"messages": [HumanMessage(content=user_query)]}

print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# Find recent AI news and summarize the top 3 articles
# ================================== Ai Message ==================================
# Tool Calls:
#   search_tool (call_Y87XMu0XU9ac8dbiV1FOupji)
#  Call ID: call_Y87XMu0XU9ac8dbiV1FOupji
#   Args:
#     query: recent AI news
# ================================= Tool Message =================================
# Name: search_tool
#
# [{"title": "AI News September 2025: In-Depth and Concise - The AI Track", "url": "https://theaitrack.com/ai-news-september-2025-in-depth-and-concise/", "content": "## Latest AI News [...] The AI Track\nThe AI Track\nThe AI Track\nThe AI Track\n\n# AI News September 2025: In-Depth and Concise\n\n## Welcome to The AI Track's comprehensive monthly roundup of the latest AI news!\n\nEach month, we compile significant news, trends, and happenings in AI, providing detailed summaries with key points in bullet form for concise yet complete understanding. [...] Oracle in Talks With Meta on $20 Billion AI Cloud Deal\n Huawei Unveils \u201cMost Powerful\u201d AI Chip Cluster to Rival Nvidia\n Huawei and Zhejiang University Launch DeepSeek-R1-Safe at Huawei Connect 2025\n Nvidia will Invest in Intel $5 Billion, Forming Strategic AI and Chip Collaboration\n Luma AI Launches Ray3, the First Video Model Designed to Reason\n AI Model Delphi-2M Predicts Disease Risks Across 1,258 Conditions Over 20 Years", "score": 0.7185356}, {"title": "25 Tech News and AI Developments This Week In September 2025", "url": "https://vavoza.com/25-tech-news-and-ai-developments-this-week-in-september-2025-vz5/", "content": "Picture of Vavoza Team\n\n# 25 Tech News and AI Developments This Week In September 2025\n\nHere are the latest 25 technology news, AI developments, and business announcements that happened this week in September 2025:\n\n## This Week\u2019s Tech News and AI Developments\n\nai-artificial-intelligence-technology-microchip\n\n## This Week\u2019s Trending AI Tools\n\nYou may also want to check out some of our other recent updates. [...] ### Consistency Trend: Viral Social Media Content Idea\n\nKonskie,,Poland,-,April,13,,2019:,Man,Holding,Smartphone,With\n\n### Stability AI Launches Image Services On Amazon Bedrock\n\nMadrid,,Spain;,05,28,2025,Close-up,Of,Hand,Holding,A\n\n### Perplexity Update: New Connectors, Memory, and Enterprise Max\n\nDubai,,United,Arab,Emirates,-,July,11,2023:,Snapchat,Application\n\n### Snapchat Hits 1 Trillion Selfies With AI and AR Lenses\n\nMulti-ethnic,Group,Of,Business,People,Sitting,In,Row,In,Modern [...] Subscribe to Vavoza Insider to access the latest business and marketing insights, news, and trends daily with unmatched speed and conciseness! \ud83d\uddde\ufe0f\n\n## Share With Your Audience\n\nVavoza Insider\n\nSubscribe to access the latest business and marketing insights, news, and trends daily with unmatched speed and conciseness\n\nMan examines AI robot in futuristic office\n\n### This Week\u2019s Biggest Tech News and AI Tools: September 2025\n\nChiang,Mai,,Thailand,-,Sep,19,2024:,A,Close-up,Of", "score": 0.7004242}, {"title": "AI News & Artificial Intelligence | TechCrunch", "url": "https://techcrunch.com/category/artificial-intelligence/", "content": "### Google and PayPal team up on agentic commerce\n\nthe NVIDIA booth at the 3rd China International Supply Chain Expo in Beijing, China, on July 20, 2025\n\n### Nvidia buys $5B stake in Intel, planning AI chip collaboration\n\nTechCrunch Disrupt 2025 Thomas Wolf\n\n### Building the future of Open AI with Thomas Wolf at TechCrunch Disrupt 2025\n\nAtlassian, Mike Cannon-Brookes\n\n### Atlassian acquires DX, a developer productivity platform, for $1B\n\nGoogle Gemini Nano Banana India trends [...] ### India leads the way on Google\u2019s Nano Banana with a local creative twist\n\n### Meta unveils new smart glasses with a display and wristband controller\n\nGroq AI chip\n\n### Nvidia AI chip challenger Groq raises even more than expected, hits $6.9B valuation\n\nThe two co-founders stand abreast in an office hallway wearing black logo t-shirts.\n\n### Irregular raises $80 million to secure frontier AI models\n\nThe two founders standing next to each other [...] ### Tim Cook, Sam Altman, and more attend Trump\u2019s UK state banquet\n\n### Notion launches agents for data analysis and task automation\n\n### Google now lets you share your custom Gemini AI assistant ...
# ================================== Ai Message ==================================
# Tool Calls:
#   news_summarizer_tool (call_2JSEmPGrFid1aHvdbA9A7Ne4)
#  Call ID: call_2JSEmPGrFid1aHvdbA9A7Ne4
#   Args:
#     news_content: ## AI News September 2025: In-Depth and Concise - The AI Track
#
# ### Key Highlights:
# 1. **Oracle in Talks With Meta**: Oracle is negotiating a $20 billion AI cloud deal with Meta.
# 2. **Huawei's New AI Chip Cluster**: Huawei has unveiled what it claims is the most powerful AI chip cluster aimed at rivaling Nvidia.
# 3. **Nvidia and Intel Collaboration**: Nvidia plans to invest $5 billion in Intel to form a strategic collaboration on AI and chip development.
# 4. **Luma AI’s Ray3 Launch**: Luma AI has launched Ray3, the first video model designed for reasoning capabilities.
# 5. **AI Model Delphi-2M**: A new AI model, Delphi-2M, has been developed to predict disease risks across 1,258 conditions over a span of 20 years.
#   news_summarizer_tool (call_Mit4nRfxmZBdbDsV2vUd30gx)
#  Call ID: call_Mit4nRfxmZBdbDsV2vUd30gx
#   Args:
#     news_content: # 25 Tech News and AI Developments This Week In September 2025
#
# ### Highlights:
# 1. **Stability AI Launches Image Services**: Stability AI has launched new image services on Amazon Bedrock.
# 2. **Snapchat Milestone**: Snapchat achieves a milestone with over 1 trillion selfies taken using AI and AR lenses.
# 3. **Perplexity Update**: The AI tool Perplexity has been updated with new connectors and memory features for enhanced performance.
#   news_summarizer_tool (call_FTOE24PvRr3HQBcc0bOjutgK)
#  Call ID: call_FTOE24PvRr3HQBcc0bOjutgK
#   Args:
#     news_content: ### AI News & Artificial Intelligence | TechCrunch
#
# ### Recent Developments:
# 1. **Nvidia's Stake in Intel**: Nvidia has acquired a $5 billion stake in Intel to collaborate on AI chip technologies.
# 2. **Meta's Smart Glasses**: Meta has introduced new smart glasses equipped with a display and a wristband controller.
# 3. **Google's Advances in AI**: Google is enhancing its AI capabilities by introducing new features in its Gemini AI assistant, including sharing custom AI assistants.
# ================================= Tool Message =================================
# Name: news_summarizer_tool
#
# "\ud83d\udcca **NEWS SUMMARY**\n==================================================\n\n    \ud83d\udcf0 **News Article**\n    \ud83d\udd17 \n    \ud83d\udcdd **Summary:** ### AI News & Artificial Intelligence | TechCrunch\n\n### Recent Developments:\n1. **Nvidia's Stake in Intel**: Nvidia has acquired a $5 billion stake in Intel to collaborate on AI chip technologies.\n2. ...\n    "
# ================================== Ai Message ==================================
#
# Here are summaries of the top three recent articles related to AI news:
#
# ### 1. **AI News September 2025: In-Depth and Concise - The AI Track**
# - **Oracle in Talks With Meta**: Oracle is negotiating a significant $20 billion AI cloud deal with Meta.
# - **Huawei's New AI Chip Cluster**: Huawei has unveiled what it claims is the most powerful AI chip cluster designed to compete with Nvidia's offerings.
# - **Nvidia and Intel Collaboration**: Nvidia plans to invest $5 billion in Intel to foster a strategic partnership focusing on AI and chip technologies.
# - **Luma AI’s Ray3 Launch**: Luma AI launched Ray3, the first video model engineered for reasoning capabilities.
# - **AI Model Delphi-2M**: The new AI model Delphi-2M can predict disease risks across 1,258 conditions over the next 20 years.
#
# ### 2. **25 Tech News and AI Developments This Week In September 2025**
# - **Stability AI Launches Image Services**: Stability AI has introduced new image services on Amazon Bedrock, expanding its offerings.
# - **Snapchat Milestone**: Snapchat has reached a notable milestone with over 1 trillion selfies taken using its AI and augmented reality lenses.
# - **Perplexity Update**: The AI tool Perplexity received an update that includes new connectors and memory features, enhancing its functionality.
#
# ### 3. **AI News & Artificial Intelligence | TechCrunch**
# - **Nvidia's Stake in Intel**: Nvidia has made a $5 billion investment in Intel to collaborate on developing AI chip technologies.
# - **Meta's Smart Glasses**: Meta has unveiled new smart glasses that come with a display and a wristband controller, marking a step forward in wearable technology.
# - **Google's Advances in AI**: Google is improving its AI capabilities by rolling out new features in its Gemini AI assistant, including the ability to share custom AI assistants.
#
# These articles highlight significant developments in AI, reflecting ongoing collaborations, technological advancements, and milestones achieved in the field.
